# %%
import torch
import numpy as np
from scipy.io import mmread
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv
from sklearn.metrics.pairwise import euclidean_distances
import torch.optim as optim
from sklearn.cluster import KMeans
import torch_geometric.utils as pyg_utils

# %%
#check cuda 
print(torch.cuda.is_available()) 
print(torch.version.cuda)
print(torch.__version__)
# Out:
# True
# 12.4
# 2.4.1

# %%
rawData = mmread('../scRNA.mtx')
coo_matrix = rawData.tocoo()
print(coo_matrix)
print(coo_matrix.shape)
# Out:
# <COOrdinate sparse matrix of dtype 'float64'
# 	with 86422438 stored elements and shape (34619, 27180)>
#   Coords	Values
#   (30, 0)	878.85046
#   (44, 0)	2636.5513
#   (58, 0)	878.85046
#   (74, 0)	878.85046
#   (77, 0)	878.85046
#   (109, 0)	878.85046
#   (225, 0)	3515.4019
#   (247, 0)	878.85046
#   (272, 0)	878.85046
#   (273, 0)	1318.2756
#   (365, 0)	878.85046
#   (366, 0)	2636.5513
#   (421, 0)	878.85046
#   (431, 0)	1757.7009
#   (440, 0)	878.85046
#   (442, 0)	5273.1025
#   (499, 0)	16698.158
#   (594, 0)	878.85046
#   (649, 0)	1757.7009
#   (688, 0)	878.85046
#   (706, 0)	878.85046
#   (831, 0)	1757.7009
#   (835, 0)	2636.5513
#   (867, 0)	878.85046
#   (911, 0)	2636.5513
#   :	:
#   (32162, 27179)	142.14685
#   (32202, 27179)	88.841736
#   (32298, 27179)	177.68347
#   (32423, 27179)	59.227825
#   (32425, 27179)	177.68347
#   (32564, 27179)	88.841736
#   (33015, 27179)	177.68347
#   (33454, 27179)	177.68347
#   (33504, 27179)	177.68347
#   (33538, 27179)	177.68347
#   (33578, 27179)	88.841736
#   (33636, 27179)	177.68347
#   (33647, 27179)	284.01257
#   (33727, 27179)	88.841736
#   (33783, 27179)	177.68347
#   (33801, 27179)	177.68347
#   (33809, 27179)	177.68347
#   (33814, 27179)	177.68347
#   (33955, 27179)	177.68347
#   (34155, 27179)	59.227825
#   (34157, 27179)	355.36694
#   (34188, 27179)	1.9998602
#   (34279, 27179)	177.68347
#   (34368, 27179)	88.841736
#   (34393, 27179)	1602.0801
# (34619, 27180)

# %%
def clean_and_split_data(coo_matrix, max_number):
    #get only non-zero values
    total_nnz = coo_matrix.nnz 

    # Ensure max_nnz doesn’t exceed total
    if max_number >= total_nnz:
        raise ValueError(f"max_nnz ({max_number}) must be less than total non-zero elements ({total_nnz})")
    
    rows = coo_matrix.row
    cols = coo_matrix.col
    data = coo_matrix.data
    
    selected_indices = np.arange(max_number)  

    selected = coo_matrix.__class__(
        (data[selected_indices], (rows[selected_indices], cols[selected_indices])),
        shape=coo_matrix.shape
    )
    
    return selected

processed_data = clean_and_split_data(coo_matrix=coo_matrix, max_number=50000)
print(processed_data)
# Out:
# <COOrdinate sparse matrix of dtype 'float64'
# 	with 50000 stored elements and shape (34619, 27180)>
#   Coords	Values
#   (30, 0)	878.85046
#   (44, 0)	2636.5513
#   (58, 0)	878.85046
#   (74, 0)	878.85046
#   (77, 0)	878.85046
#   (109, 0)	878.85046
#   (225, 0)	3515.4019
#   (247, 0)	878.85046
#   (272, 0)	878.85046
#   (273, 0)	1318.2756
#   (365, 0)	878.85046
#   (366, 0)	2636.5513
#   (421, 0)	878.85046
#   (431, 0)	1757.7009
#   (440, 0)	878.85046
#   (442, 0)	5273.1025
#   (499, 0)	16698.158
#   (594, 0)	878.85046
#   (649, 0)	1757.7009
#   (688, 0)	878.85046
#   (706, 0)	878.85046
#   (831, 0)	1757.7009
#   (835, 0)	2636.5513
#   (867, 0)	878.85046
#   (911, 0)	2636.5513
#   :	:
#   (12449, 15)	35.81332
#   (12455, 15)	214.87991
#   (12457, 15)	35.81332
#   (12463, 15)	35.81332
#   (12472, 15)	35.81332
#   (12478, 15)	214.87991
#   (12482, 15)	35.81332
#   (12490, 15)	35.81332
#   (12500, 15)	71.62664
#   (12503, 15)	107.43996
#   (12505, 15)	143.25328
#   (12508, 15)	429.75983
#   (12511, 15)	179.0666
#   (12514, 15)	35.81332
#   (12520, 15)	250.69324
#   (12525, 15)	35.81332
#   (12530, 15)	35.81332
#   (12533, 15)	35.81332
#   (12539, 15)	107.43996
#   (12541, 15)	71.62664
#   (12546, 15)	35.81332
#   (12554, 15)	107.43996
#   (12555, 15)	71.62664
#   (12557, 15)	35.81332
#   (12559, 15)	35.81332

# %%
def build_cell_to_cell_graph_normal(data, threshold):   

    gene_expression = data.data
    outliers = []
    x = torch.tensor(gene_expression, dtype=torch.float32).unsqueeze(1)

    k = 2  
    distances = euclidean_distances(x, x)

    edge_index_list = []

    for i in range(len(gene_expression)):
        nearest_neighbors = np.argsort(distances[i])[1:k+1]  
        for j in nearest_neighbors:
            if distances[i, j] <= threshold:
                edge_index_list.append((i, j))
            else:
                outliers.append(int(j))

    edge_index_np = np.array(edge_index_list).T
    edge_index = torch.tensor(edge_index_np, dtype=torch.long) if edge_index_np.size > 0 else torch.empty((2, 0), dtype=torch.long)

    source_cells = edge_index_np[0]
    target_cells = edge_index_np[1]

    # for src, tgt in zip(source_cells, target_cells):
    #     print(f"Cell {src} is connected to Cell {tgt}")

  
    cleaned_outliers = list(set(outliers))
    print(cleaned_outliers)
    
  
    data = Data(edge_index=edge_index, x=x)
    return data

py_data = build_cell_to_cell_graph_normal(processed_data, threshold=500)
# Out:
# c:\Users\shera\anaconda3\envs\scRareCellDetect\Lib\site-packages\sklearn\metrics\pairwise.py:611: RuntimeWarning: overflow encountered in scalar multiply
#   + (x_density * n_samples_X * y_density * n_samples_Y)
# Cell 0 is connected to Cell 360
# Cell 0 is connected to Cell 359
# Cell 1 is connected to Cell 22
# Cell 1 is connected to Cell 508
# Cell 2 is connected to Cell 360
# Cell 2 is connected to Cell 359
# Cell 3 is connected to Cell 360
# Cell 3 is connected to Cell 359
# Cell 4 is connected to Cell 360
# Cell 4 is connected to Cell 359
# Cell 5 is connected to Cell 360
# Cell 5 is connected to Cell 359
# Cell 6 is connected to Cell 510
# Cell 6 is connected to Cell 506
# Cell 7 is connected to Cell 360
# Cell 7 is connected to Cell 359
# Cell 8 is connected to Cell 360
# Cell 8 is connected to Cell 359
# Cell 9 is connected to Cell 562
# Cell 9 is connected to Cell 39547
# Cell 10 is connected to Cell 360
# Cell 10 is connected to Cell 359
# Cell 11 is connected to Cell 22
# Cell 11 is connected to Cell 508
# Cell 12 is connected to Cell 360
# Cell 12 is connected to Cell 359
# Cell 13 is connected to Cell 498
# Cell 13 is connected to Cell 169
# Cell 14 is connected to Cell 360
# Cell 14 is connected to Cell 359
# Cell 15 is connected to Cell 279
# Cell 15 is connected to Cell 313
# Cell 16 is connected to Cell 256
# Cell 16 is connected to Cell 42144
# Cell 17 is connected to Cell 360
# Cell 17 is connected to Cell 359
# Cell 18 is connected to Cell 498
# Cell 18 is connected to Cell 169
# Cell 19 is connected to Cell 360
# Cell 19 is connected to Cell 359
# Cell 20 is connected to Cell 360
# Cell 20 is connected to Cell 359
# Cell 21 is connected to Cell 498
# Cell 21 is connected to Cell 169
# Cell 22 is connected to Cell 22
# Cell 22 is connected to Cell 508
# Cell 23 is connected to Cell 360
# Cell 23 is connected to Cell 359
# Cell 24 is connected to Cell 22
# Cell 24 is connected to Cell 508
# Cell 25 is connected to Cell 360
# Cell 25 is connected to Cell 359
# Cell 26 is connected to Cell 360
# Cell 26 is connected to Cell 359
# Cell 27 is connected to Cell 360
# Cell 27 is connected to Cell 359
# Cell 28 is connected to Cell 360
# Cell 28 is connected to Cell 359
# Cell 29 is connected to Cell 510
# Cell 29 is connected to Cell 506
# Cell 30 is connected to Cell 498
# Cell 30 is connected to Cell 169
# Cell 31 is connected to Cell 360
# Cell 31 is connected to Cell 359
# Cell 32 is connected to Cell 498
# Cell 32 is connected to Cell 169
# Cell 33 is connected to Cell 360
# Cell 33 is connected to Cell 359
# Cell 34 is connected to Cell 360
# Cell 34 is connected to Cell 359
# Cell 35 is connected to Cell 360
# Cell 35 is connected to Cell 359
# Cell 36 is connected to Cell 360
# Cell 36 is connected to Cell 359
# Cell 37 is connected to Cell 498
# Cell 37 is connected to Cell 169
# Cell 38 is connected to Cell 360
# Cell 38 is connected to Cell 359
# Cell 39 is connected to Cell 360
# Cell 39 is connected to Cell 359
# Cell 40 is connected to Cell 498
# Cell 40 is connected to Cell 169
# Cell 41 is connected to Cell 360
# Cell 41 is connected to Cell 359
# Cell 42 is connected to Cell 360
# Cell 42 is connected to Cell 359
# Cell 43 is connected to Cell 360
# Cell 43 is connected to Cell 359
# Cell 44 is connected to Cell 22
# Cell 44 is connected to Cell 508
# Cell 45 is connected to Cell 360
# Cell 45 is connected to Cell 359
# Cell 46 is connected to Cell 498
# Cell 46 is connected to Cell 169
# Cell 47 is connected to Cell 498
# Cell 47 is connected to Cell 169
# Cell 48 is connected to Cell 296
# Cell 48 is connected to Cell 417
# Cell 49 is connected to Cell 22
# Cell 49 is connected to Cell 508
# Cell 50 is connected to Cell 498
# Cell 50 is connected to Cell 169
# Cell 51 is connected to Cell 360
# Cell 51 is connected to Cell 359
# Cell 52 is connected to Cell 498
# Cell 52 is connected to Cell 169
# Cell 53 is connected to Cell 360
# Cell 53 is connected to Cell 359
# Cell 54 is connected to Cell 360
# Cell 54 is connected to Cell 359
# Cell 55 is connected to Cell 174
# Cell 55 is connected to Cell 74
# Cell 56 is connected to Cell 510
# Cell 56 is connected to Cell 506
# Cell 57 is connected to Cell 360
# Cell 57 is connected to Cell 359
# Cell 58 is connected to Cell 360
# Cell 58 is connected to Cell 359
# Cell 59 is connected to Cell 360
# Cell 59 is connected to Cell 359
# Cell 60 is connected to Cell 296
# Cell 60 is connected to Cell 417
# Cell 61 is connected to Cell 360
# Cell 61 is connected to Cell 359
# Cell 62 is connected to Cell 360
# Cell 62 is connected to Cell 359
# Cell 63 is connected to Cell 296
# Cell 63 is connected to Cell 417
# Cell 64 is connected to Cell 360
# Cell 64 is connected to Cell 359
# Cell 65 is connected to Cell 498
# Cell 65 is connected to Cell 169
# Cell 66 is connected to Cell 360
# Cell 66 is connected to Cell 359
# Cell 67 is connected to Cell 360
# Cell 67 is connected to Cell 359
# Cell 68 is connected to Cell 360
# Cell 68 is connected to Cell 359
# Cell 69 is connected to Cell 360
# Cell 69 is connected to Cell 359
# Cell 70 is connected to Cell 360
# Cell 70 is connected to Cell 359
# Cell 71 is connected to Cell 360
# Cell 71 is connected to Cell 359
# Cell 72 is connected to Cell 360
# Cell 72 is connected to Cell 359
# Cell 73 is connected to Cell 360
# Cell 73 is connected to Cell 359
# Cell 74 is connected to Cell 174
# Cell 74 is connected to Cell 74
# Cell 75 is connected to Cell 498
# Cell 75 is connected to Cell 169
# Cell 76 is connected to Cell 360
# Cell 76 is connected to Cell 359
# Cell 77 is connected to Cell 360
# Cell 77 is connected to Cell 359
# Cell 78 is connected to Cell 360
# Cell 78 is connected to Cell 359
# Cell 79 is connected to Cell 360
# Cell 79 is connected to Cell 359
# Cell 80 is connected to Cell 360
# Cell 80 is connected to Cell 359
# Cell 81 is connected to Cell 360
# Cell 81 is connected to Cell 359
# Cell 82 is connected to Cell 360
# Cell 82 is connected to Cell 359
# Cell 83 is connected to Cell 360
# Cell 83 is connected to Cell 359
# Cell 84 is connected to Cell 360
# Cell 84 is connected to Cell 359
# Cell 85 is connected to Cell 498
# Cell 85 is connected to Cell 169
# Cell 86 is connected to Cell 498
# Cell 86 is connected to Cell 169
# Cell 87 is connected to Cell 360
# Cell 87 is connected to Cell 359
# Cell 88 is connected to Cell 498
# Cell 88 is connected to Cell 169
# Cell 89 is connected to Cell 360
# Cell 89 is connected to Cell 359
# Cell 90 is connected to Cell 360
# Cell 90 is connected to Cell 359
# Cell 91 is connected to Cell 296
# Cell 91 is connected to Cell 417
# Cell 92 is connected to Cell 360
# Cell 92 is connected to Cell 359
# Cell 93 is connected to Cell 360
# Cell 93 is connected to Cell 359
# Cell 94 is connected to Cell 528
# Cell 94 is connected to Cell 94
# Cell 95 is connected to Cell 95
# Cell 95 is connected to Cell 502
# Cell 96 is connected to Cell 360
# Cell 96 is connected to Cell 359
# Cell 97 is connected to Cell 498
# Cell 97 is connected to Cell 169
# Cell 98 is connected to Cell 360
# Cell 98 is connected to Cell 359
# Cell 99 is connected to Cell 360
# Cell 99 is connected to Cell 359
# Cell 100 is connected to Cell 360
# Cell 100 is connected to Cell 359
# Cell 101 is connected to Cell 360
# Cell 101 is connected to Cell 359
# Cell 102 is connected to Cell 590
# Cell 102 is connected to Cell 12500
# Cell 103 is connected to Cell 360
# Cell 103 is connected to Cell 359
# Cell 104 is connected to Cell 498
# Cell 104 is connected to Cell 169
# Cell 105 is connected to Cell 360
# Cell 105 is connected to Cell 359
# Cell 106 is connected to Cell 360
# Cell 106 is connected to Cell 359
# Cell 107 is connected to Cell 296
# Cell 107 is connected to Cell 417
# Cell 108 is connected to Cell 360
# Cell 108 is connected to Cell 359
# Cell 109 is connected to Cell 510
# Cell 109 is connected to Cell 506
# Cell 110 is connected to Cell 510
# Cell 110 is connected to Cell 506
# Cell 111 is connected to Cell 498
# Cell 111 is connected to Cell 169
# Cell 112 is connected to Cell 498
# Cell 112 is connected to Cell 169
# Cell 113 is connected to Cell 360
# Cell 113 is connected to Cell 359
# Cell 114 is connected to Cell 498
# Cell 114 is connected to Cell 169
# Cell 115 is connected to Cell 360
# Cell 115 is connected to Cell 359
# Cell 116 is connected to Cell 498
# Cell 116 is connected to Cell 169
# Cell 117 is connected to Cell 498
# Cell 117 is connected to Cell 169
# Cell 118 is connected to Cell 498
# Cell 118 is connected to Cell 169
# Cell 119 is connected to Cell 296
# Cell 119 is connected to Cell 417
# Cell 120 is connected to Cell 360
# Cell 120 is connected to Cell 359
# Cell 121 is connected to Cell 498
# Cell 121 is connected to Cell 169
# Cell 122 is connected to Cell 510
# Cell 122 is connected to Cell 506
# Cell 123 is connected to Cell 360
# Cell 123 is connected to Cell 359
# Cell 124 is connected to Cell 360
# Cell 124 is connected to Cell 359
# Cell 125 is connected to Cell 174
# Cell 125 is connected to Cell 74
# Cell 126 is connected to Cell 360
# Cell 126 is connected to Cell 359
# Cell 127 is connected to Cell 360
# Cell 127 is connected to Cell 359
# Cell 128 is connected to Cell 31270
# Cell 128 is connected to Cell 16287
# Cell 129 is connected to Cell 360
# Cell 129 is connected to Cell 359
# Cell 130 is connected to Cell 360
# Cell 130 is connected to Cell 359
# Cell 131 is connected to Cell 360
# Cell 131 is connected to Cell 359
# Cell 132 is connected to Cell 360
# Cell 132 is connected to Cell 359
# Cell 133 is connected to Cell 279
# Cell 133 is connected to Cell 313
# Cell 134 is connected to Cell 360
# Cell 134 is connected to Cell 359
# Cell 135 is connected to Cell 360
# Cell 135 is connected to Cell 359
# Cell 136 is connected to Cell 360
# Cell 136 is connected to Cell 359
# Cell 137 is connected to Cell 22
# Cell 137 is connected to Cell 508
# Cell 138 is connected to Cell 360
# Cell 138 is connected to Cell 359
# Cell 139 is connected to Cell 360
# Cell 139 is connected to Cell 359
# Cell 140 is connected to Cell 360
# Cell 140 is connected to Cell 359
# Cell 141 is connected to Cell 360
# Cell 141 is connected to Cell 359
# Cell 142 is connected to Cell 498
# Cell 142 is connected to Cell 169
# Cell 143 is connected to Cell 360
# Cell 143 is connected to Cell 359
# Cell 144 is connected to Cell 360
# Cell 144 is connected to Cell 359
# Cell 145 is connected to Cell 360
# Cell 145 is connected to Cell 359
# Cell 146 is connected to Cell 360
# Cell 146 is connected to Cell 359
# Cell 147 is connected to Cell 498
# Cell 147 is connected to Cell 169
# Cell 148 is connected to Cell 360
# Cell 148 is connected to Cell 359
# Cell 149 is connected to Cell 360
# Cell 149 is connected to Cell 359
# Cell 150 is connected to Cell 360
# Cell 150 is connected to Cell 359
# Cell 151 is connected to Cell 360
# Cell 151 is connected to Cell 359
# Cell 152 is connected to Cell 360
# Cell 152 is connected to Cell 359
# Cell 153 is connected to Cell 498
# Cell 153 is connected to Cell 169
# Cell 154 is connected to Cell 360
# Cell 154 is connected to Cell 359
# Cell 155 is connected to Cell 360
# Cell 155 is connected to Cell 359
# Cell 156 is connected to Cell 22
# Cell 156 is connected to Cell 508
# Cell 157 is connected to Cell 360
# Cell 157 is connected to Cell 359
# Cell 158 is connected to Cell 360
# Cell 158 is connected to Cell 359
# Cell 159 is connected to Cell 22
# Cell 159 is connected to Cell 508
# Cell 160 is connected to Cell 360
# Cell 160 is connected to Cell 359
# Cell 161 is connected to Cell 360
# Cell 161 is connected to Cell 359
# Cell 162 is connected to Cell 360
# Cell 162 is connected to Cell 359
# Cell 163 is connected to Cell 360
# Cell 163 is connected to Cell 359
# Cell 164 is connected to Cell 360
# Cell 164 is connected to Cell 359
# Cell 165 is connected to Cell 498
# Cell 165 is connected to Cell 169
# Cell 166 is connected to Cell 360
# Cell 166 is connected to Cell 359
# Cell 167 is connected to Cell 22
# Cell 167 is connected to Cell 508
# Cell 168 is connected to Cell 360
# Cell 168 is connected to Cell 359
# Cell 169 is connected to Cell 498
# Cell 169 is connected to Cell 169
# Cell 170 is connected to Cell 360
# Cell 170 is connected to Cell 359
# Cell 171 is connected to Cell 360
# Cell 171 is connected to Cell 359
# Cell 172 is connected to Cell 510
# Cell 172 is connected to Cell 506
# Cell 173 is connected to Cell 279
# Cell 173 is connected to Cell 313
# Cell 174 is connected to Cell 174
# Cell 174 is connected to Cell 74
# Cell 175 is connected to Cell 360
# Cell 175 is connected to Cell 359
# Cell 176 is connected to Cell 360
# Cell 176 is connected to Cell 359
# Cell 177 is connected to Cell 498
# Cell 177 is connected to Cell 169
# Cell 178 is connected to Cell 279
# Cell 178 is connected to Cell 313
# Cell 179 is connected to Cell 174
# Cell 179 is connected to Cell 74
# Cell 180 is connected to Cell 360
# Cell 180 is connected to Cell 359
# Cell 181 is connected to Cell 360
# Cell 181 is connected to Cell 359
# Cell 182 is connected to Cell 279
# Cell 182 is connected to Cell 313
# Cell 183 is connected to Cell 360
# Cell 183 is connected to Cell 359
# Cell 184 is connected to Cell 296
# Cell 184 is connected to Cell 417
# Cell 185 is connected to Cell 360
# Cell 185 is connected to Cell 359
# Cell 186 is connected to Cell 22
# Cell 186 is connected to Cell 508
# Cell 187 is connected to Cell 360
# Cell 187 is connected to Cell 359
# Cell 188 is connected to Cell 360
# Cell 188 is connected to Cell 359
# Cell 189 is connected to Cell 360
# Cell 189 is connected to Cell 359
# Cell 190 is connected to Cell 360
# Cell 190 is connected to Cell 359
# Cell 191 is connected to Cell 360
# Cell 191 is connected to Cell 359
# Cell 192 is connected to Cell 360
# Cell 192 is connected to Cell 359
# Cell 193 is connected to Cell 360
# Cell 193 is connected to Cell 359
# Cell 194 is connected to Cell 22
# Cell 194 is connected to Cell 508
# Cell 195 is connected to Cell 360
# Cell 195 is connected to Cell 359
# Cell 196 is connected to Cell 360
# Cell 196 is connected to Cell 359
# Cell 197 is connected to Cell 174
# Cell 197 is connected to Cell 74
# Cell 198 is connected to Cell 360
# Cell 198 is connected to Cell 359
# Cell 199 is connected to Cell 360
# Cell 199 is connected to Cell 359
# Cell 200 is connected to Cell 360
# Cell 200 is connected to Cell 359
# Cell 201 is connected to Cell 498
# Cell 201 is connected to Cell 169
# Cell 202 is connected to Cell 498
# Cell 202 is connected to Cell 169
# Cell 203 is connected to Cell 360
# Cell 203 is connected to Cell 359
# Cell 204 is connected to Cell 360
# Cell 204 is connected to Cell 359
# Cell 205 is connected to Cell 360
# Cell 205 is connected to Cell 359
# Cell 206 is connected to Cell 360
# Cell 206 is connected to Cell 359
# Cell 207 is connected to Cell 360
# Cell 207 is connected to Cell 359
# Cell 208 is connected to Cell 360
# Cell 208 is connected to Cell 359
# Cell 209 is connected to Cell 360
# Cell 209 is connected to Cell 359
# Cell 210 is connected to Cell 360
# Cell 210 is connected to Cell 359
# Cell 211 is connected to Cell 498
# Cell 211 is connected to Cell 169
# Cell 212 is connected to Cell 360
# Cell 212 is connected to Cell 359
# Cell 213 is connected to Cell 498
# Cell 213 is connected to Cell 169
# Cell 214 is connected to Cell 360
# Cell 214 is connected to Cell 359
# Cell 215 is connected to Cell 279
# Cell 215 is connected to Cell 313
# Cell 216 is connected to Cell 360
# Cell 216 is connected to Cell 359
# Cell 217 is connected to Cell 360
# Cell 217 is connected to Cell 359
# Cell 218 is connected to Cell 360
# Cell 218 is connected to Cell 359
# Cell 219 is connected to Cell 314
# Cell 219 is connected to Cell 503
# Cell 220 is connected to Cell 22
# Cell 220 is connected to Cell 508
# Cell 221 is connected to Cell 360
# Cell 221 is connected to Cell 359
# Cell 222 is connected to Cell 360
# Cell 222 is connected to Cell 359
# Cell 223 is connected to Cell 360
# Cell 223 is connected to Cell 359
# Cell 224 is connected to Cell 360
# Cell 224 is connected to Cell 359
# Cell 225 is connected to Cell 296
# Cell 225 is connected to Cell 417
# Cell 226 is connected to Cell 360
# Cell 226 is connected to Cell 359
# Cell 227 is connected to Cell 498
# Cell 227 is connected to Cell 169
# Cell 228 is connected to Cell 360
# Cell 228 is connected to Cell 359
# Cell 229 is connected to Cell 498
# Cell 229 is connected to Cell 169
# Cell 230 is connected to Cell 305
# Cell 230 is connected to Cell 573
# Cell 231 is connected to Cell 360
# Cell 231 is connected to Cell 359
# Cell 232 is connected to Cell 174
# Cell 232 is connected to Cell 74
# Cell 233 is connected to Cell 360
# Cell 233 is connected to Cell 359
# Cell 234 is connected to Cell 498
# Cell 234 is connected to Cell 169
# Cell 235 is connected to Cell 360
# Cell 235 is connected to Cell 359
# Cell 236 is connected to Cell 510
# Cell 236 is connected to Cell 506
# Cell 237 is connected to Cell 510
# Cell 237 is connected to Cell 506
# Cell 238 is connected to Cell 360
# Cell 238 is connected to Cell 359
# Cell 240 is connected to Cell 174
# Cell 240 is connected to Cell 74
# Cell 241 is connected to Cell 360
# Cell 241 is connected to Cell 359
# Cell 242 is connected to Cell 360
# Cell 242 is connected to Cell 359
# Cell 243 is connected to Cell 360
# Cell 243 is connected to Cell 359
# Cell 244 is connected to Cell 314
# Cell 244 is connected to Cell 503
# Cell 245 is connected to Cell 360
# Cell 245 is connected to Cell 359
# Cell 246 is connected to Cell 360
# Cell 246 is connected to Cell 359
# Cell 247 is connected to Cell 498
# Cell 247 is connected to Cell 169
# Cell 248 is connected to Cell 360
# Cell 248 is connected to Cell 359
# Cell 249 is connected to Cell 498
# Cell 249 is connected to Cell 169
# Cell 250 is connected to Cell 510
# Cell 250 is connected to Cell 506
# Cell 251 is connected to Cell 22
# Cell 251 is connected to Cell 508
# Cell 252 is connected to Cell 360
# Cell 252 is connected to Cell 359
# Cell 253 is connected to Cell 498
# Cell 253 is connected to Cell 169
# Cell 254 is connected to Cell 360
# Cell 254 is connected to Cell 359
# Cell 255 is connected to Cell 498
# Cell 255 is connected to Cell 169
# Cell 256 is connected to Cell 256
# Cell 256 is connected to Cell 42144
# Cell 257 is connected to Cell 360
# Cell 257 is connected to Cell 359
# Cell 258 is connected to Cell 360
# Cell 258 is connected to Cell 359
# Cell 259 is connected to Cell 360
# Cell 259 is connected to Cell 359
# Cell 260 is connected to Cell 360
# Cell 260 is connected to Cell 359
# Cell 261 is connected to Cell 360
# Cell 261 is connected to Cell 359
# Cell 262 is connected to Cell 360
# Cell 262 is connected to Cell 359
# Cell 263 is connected to Cell 296
# Cell 263 is connected to Cell 417
# Cell 264 is connected to Cell 498
# Cell 264 is connected to Cell 169
# Cell 265 is connected to Cell 314
# Cell 265 is connected to Cell 503
# Cell 266 is connected to Cell 275
# Cell 266 is connected to Cell 22802
# Cell 267 is connected to Cell 360
# Cell 267 is connected to Cell 359
# Cell 268 is connected to Cell 360
# Cell 268 is connected to Cell 359
# Cell 269 is connected to Cell 360
# Cell 269 is connected to Cell 359
# Cell 270 is connected to Cell 360
# Cell 270 is connected to Cell 359
# Cell 271 is connected to Cell 22
# Cell 271 is connected to Cell 508
# Cell 272 is connected to Cell 360
# Cell 272 is connected to Cell 359
# Cell 273 is connected to Cell 360
# Cell 273 is connected to Cell 359
# Cell 274 is connected to Cell 360
# Cell 274 is connected to Cell 359
# Cell 275 is connected to Cell 275
# Cell 275 is connected to Cell 22802
# Cell 276 is connected to Cell 360
# Cell 276 is connected to Cell 359
# Cell 277 is connected to Cell 498
# Cell 277 is connected to Cell 169
# Cell 278 is connected to Cell 360
# Cell 278 is connected to Cell 359
# Cell 279 is connected to Cell 279
# Cell 279 is connected to Cell 313
# Cell 280 is connected to Cell 478
# Cell 280 is connected to Cell 46954
# Cell 281 is connected to Cell 360
# Cell 281 is connected to Cell 359
# Cell 282 is connected to Cell 174
# Cell 282 is connected to Cell 74
# Cell 283 is connected to Cell 360
# Cell 283 is connected to Cell 359
# Cell 284 is connected to Cell 498
# Cell 284 is connected to Cell 169
# Cell 285 is connected to Cell 360
# Cell 285 is connected to Cell 359
# Cell 286 is connected to Cell 498
# Cell 286 is connected to Cell 169
# Cell 287 is connected to Cell 360
# Cell 287 is connected to Cell 359
# Cell 288 is connected to Cell 279
# Cell 288 is connected to Cell 313
# Cell 289 is connected to Cell 174
# Cell 289 is connected to Cell 74
# Cell 290 is connected to Cell 510
# Cell 290 is connected to Cell 506
# Cell 291 is connected to Cell 360
# Cell 291 is connected to Cell 359
# Cell 292 is connected to Cell 360
# Cell 292 is connected to Cell 359
# Cell 293 is connected to Cell 360
# Cell 293 is connected to Cell 359
# Cell 294 is connected to Cell 360
# Cell 294 is connected to Cell 359
# Cell 295 is connected to Cell 360
# Cell 295 is connected to Cell 359
# Cell 296 is connected to Cell 296
# Cell 296 is connected to Cell 417
# Cell 297 is connected to Cell 360
# Cell 297 is connected to Cell 359
# Cell 298 is connected to Cell 296
# Cell 298 is connected to Cell 417
# Cell 299 is connected to Cell 498
# Cell 299 is connected to Cell 169
# Cell 300 is connected to Cell 360
# Cell 300 is connected to Cell 359
# Cell 301 is connected to Cell 360
# Cell 301 is connected to Cell 359
# Cell 302 is connected to Cell 360
# Cell 302 is connected to Cell 359
# Cell 303 is connected to Cell 360
# Cell 303 is connected to Cell 359
# Cell 304 is connected to Cell 360
# Cell 304 is connected to Cell 359
# Cell 305 is connected to Cell 305
# Cell 305 is connected to Cell 573
# Cell 306 is connected to Cell 360
# Cell 306 is connected to Cell 359
# Cell 307 is connected to Cell 360
# Cell 307 is connected to Cell 359
# Cell 308 is connected to Cell 360
# Cell 308 is connected to Cell 359
# Cell 309 is connected to Cell 360
# Cell 309 is connected to Cell 359
# Cell 310 is connected to Cell 360
# Cell 310 is connected to Cell 359
# Cell 311 is connected to Cell 360
# Cell 311 is connected to Cell 359
# Cell 312 is connected to Cell 360
# Cell 312 is connected to Cell 359
# Cell 313 is connected to Cell 279
# Cell 313 is connected to Cell 313
# Cell 314 is connected to Cell 314
# Cell 314 is connected to Cell 503
# Cell 315 is connected to Cell 360
# Cell 315 is connected to Cell 359
# Cell 316 is connected to Cell 360
# Cell 316 is connected to Cell 359
# Cell 317 is connected to Cell 498
# Cell 317 is connected to Cell 169
# Cell 318 is connected to Cell 360
# Cell 318 is connected to Cell 359
# Cell 319 is connected to Cell 360
# Cell 319 is connected to Cell 359
# Cell 320 is connected to Cell 360
# Cell 320 is connected to Cell 359
# Cell 321 is connected to Cell 360
# Cell 321 is connected to Cell 359
# Cell 322 is connected to Cell 498
# Cell 322 is connected to Cell 169
# Cell 323 is connected to Cell 360
# Cell 323 is connected to Cell 359
# Cell 324 is connected to Cell 360
# Cell 324 is connected to Cell 359
# Cell 325 is connected to Cell 360
# Cell 325 is connected to Cell 359
# Cell 326 is connected to Cell 22
# Cell 326 is connected to Cell 508
# Cell 327 is connected to Cell 360
# Cell 327 is connected to Cell 359
# Cell 328 is connected to Cell 174
# Cell 328 is connected to Cell 74
# Cell 329 is connected to Cell 360
# Cell 329 is connected to Cell 359
# Cell 330 is connected to Cell 330
# Cell 330 is connected to Cell 45180
# Cell 331 is connected to Cell 360
# Cell 331 is connected to Cell 359
# Cell 332 is connected to Cell 279
# Cell 332 is connected to Cell 313
# Cell 333 is connected to Cell 360
# Cell 333 is connected to Cell 359
# Cell 334 is connected to Cell 360
# Cell 334 is connected to Cell 359
# Cell 335 is connected to Cell 360
# Cell 335 is connected to Cell 359
# Cell 336 is connected to Cell 360
# Cell 336 is connected to Cell 359
# Cell 337 is connected to Cell 360
# Cell 337 is connected to Cell 359
# Cell 338 is connected to Cell 498
# Cell 338 is connected to Cell 169
# Cell 339 is connected to Cell 360
# Cell 339 is connected to Cell 359
# Cell 340 is connected to Cell 360
# Cell 340 is connected to Cell 359
# Cell 341 is connected to Cell 360
# Cell 341 is connected to Cell 359
# Cell 342 is connected to Cell 360
# Cell 342 is connected to Cell 359
# Cell 343 is connected to Cell 360
# Cell 343 is connected to Cell 359
# Cell 344 is connected to Cell 360
# Cell 344 is connected to Cell 359
# Cell 345 is connected to Cell 360
# Cell 345 is connected to Cell 359
# Cell 346 is connected to Cell 360
# Cell 346 is connected to Cell 359
# Cell 347 is connected to Cell 360
# Cell 347 is connected to Cell 359
# Cell 348 is connected to Cell 360
# Cell 348 is connected to Cell 359
# Cell 349 is connected to Cell 360
# Cell 349 is connected to Cell 359
# Cell 350 is connected to Cell 360
# Cell 350 is connected to Cell 359
# Cell 351 is connected to Cell 360
# Cell 351 is connected to Cell 359
# Cell 352 is connected to Cell 498
# Cell 352 is connected to Cell 169
# Cell 353 is connected to Cell 22
# Cell 353 is connected to Cell 508
# Cell 354 is connected to Cell 498
# Cell 354 is connected to Cell 169
# Cell 355 is connected to Cell 360
# Cell 355 is connected to Cell 359
# Cell 356 is connected to Cell 22
# Cell 356 is connected to Cell 508
# Cell 357 is connected to Cell 360
# Cell 357 is connected to Cell 359
# Cell 358 is connected to Cell 510
# Cell 358 is connected to Cell 506
# Cell 359 is connected to Cell 360
# Cell 359 is connected to Cell 359
# Cell 360 is connected to Cell 360
# Cell 360 is connected to Cell 359
# Cell 361 is connected to Cell 360
# Cell 361 is connected to Cell 359
# Cell 362 is connected to Cell 360
# Cell 362 is connected to Cell 359
# Cell 363 is connected to Cell 360
# Cell 363 is connected to Cell 359
# Cell 364 is connected to Cell 360
# Cell 364 is connected to Cell 359
# Cell 365 is connected to Cell 360
# Cell 365 is connected to Cell 359
# Cell 366 is connected to Cell 360
# Cell 366 is connected to Cell 359
# Cell 367 is connected to Cell 360
# Cell 367 is connected to Cell 359
# Cell 368 is connected to Cell 360
# Cell 368 is connected to Cell 359
# Cell 369 is connected to Cell 360
# Cell 369 is connected to Cell 359
# Cell 370 is connected to Cell 360
# Cell 370 is connected to Cell 359
# Cell 371 is connected to Cell 360
# Cell 371 is connected to Cell 359
# Cell 372 is connected to Cell 360
# Cell 372 is connected to Cell 359
# Cell 373 is connected to Cell 360
# Cell 373 is connected to Cell 359
# Cell 374 is connected to Cell 360
# Cell 374 is connected to Cell 359
# Cell 375 is connected to Cell 360
# Cell 375 is connected to Cell 359
# Cell 376 is connected to Cell 360
# Cell 376 is connected to Cell 359
# Cell 377 is connected to Cell 360
# Cell 377 is connected to Cell 359
# Cell 378 is connected to Cell 510
# Cell 378 is connected to Cell 506
# Cell 379 is connected to Cell 360
# Cell 379 is connected to Cell 359
# Cell 380 is connected to Cell 360
# Cell 380 is connected to Cell 359
# Cell 381 is connected to Cell 360
# Cell 381 is connected to Cell 359
# Cell 382 is connected to Cell 360
# Cell 382 is connected to Cell 359
# Cell 383 is connected to Cell 498
# Cell 383 is connected to Cell 169
# Cell 384 is connected to Cell 498
# Cell 384 is connected to Cell 169
# Cell 385 is connected to Cell 360
# Cell 385 is connected to Cell 359
# Cell 386 is connected to Cell 360
# Cell 386 is connected to Cell 359
# Cell 387 is connected to Cell 43539
# Cell 388 is connected to Cell 360
# Cell 388 is connected to Cell 359
# Cell 389 is connected to Cell 360
# Cell 389 is connected to Cell 359
# Cell 390 is connected to Cell 360
# Cell 390 is connected to Cell 359
# Cell 391 is connected to Cell 510
# Cell 391 is connected to Cell 506
# Cell 392 is connected to Cell 296
# Cell 392 is connected to Cell 417
# Cell 393 is connected to Cell 360
# Cell 393 is connected to Cell 359
# Cell 394 is connected to Cell 360
# Cell 394 is connected to Cell 359
# Cell 395 is connected to Cell 360
# Cell 395 is connected to Cell 359
# Cell 396 is connected to Cell 360
# Cell 396 is connected to Cell 359
# Cell 397 is connected to Cell 360
# Cell 397 is connected to Cell 359
# Cell 398 is connected to Cell 360
# Cell 398 is connected to Cell 359
# Cell 399 is connected to Cell 360
# Cell 399 is connected to Cell 359
# Cell 400 is connected to Cell 22
# Cell 400 is connected to Cell 508
# Cell 401 is connected to Cell 360
# Cell 401 is connected to Cell 359
# Cell 402 is connected to Cell 360
# Cell 402 is connected to Cell 359
# Cell 403 is connected to Cell 360
# Cell 403 is connected to Cell 359
# Cell 404 is connected to Cell 360
# Cell 404 is connected to Cell 359
# Cell 405 is connected to Cell 360
# Cell 405 is connected to Cell 359
# Cell 406 is connected to Cell 360
# Cell 406 is connected to Cell 359
# Cell 407 is connected to Cell 360
# Cell 407 is connected to Cell 359
# Cell 408 is connected to Cell 360
# Cell 408 is connected to Cell 359
# Cell 409 is connected to Cell 174
# Cell 409 is connected to Cell 74
# Cell 410 is connected to Cell 314
# Cell 410 is connected to Cell 503
# Cell 411 is connected to Cell 360
# Cell 411 is connected to Cell 359
# Cell 412 is connected to Cell 360
# Cell 412 is connected to Cell 359
# Cell 413 is connected to Cell 360
# Cell 413 is connected to Cell 359
# Cell 414 is connected to Cell 360
# Cell 414 is connected to Cell 359
# Cell 415 is connected to Cell 360
# Cell 415 is connected to Cell 359
# Cell 416 is connected to Cell 360
# Cell 416 is connected to Cell 359
# Cell 417 is connected to Cell 296
# Cell 417 is connected to Cell 417
# Cell 418 is connected to Cell 360
# Cell 418 is connected to Cell 359
# Cell 419 is connected to Cell 360
# Cell 419 is connected to Cell 359
# Cell 420 is connected to Cell 498
# Cell 420 is connected to Cell 169
# Cell 421 is connected to Cell 360
# Cell 421 is connected to Cell 359
# Cell 422 is connected to Cell 22
# Cell 422 is connected to Cell 508
# Cell 423 is connected to Cell 360
# Cell 423 is connected to Cell 359
# Cell 424 is connected to Cell 360
# Cell 424 is connected to Cell 359
# Cell 425 is connected to Cell 22
# Cell 425 is connected to Cell 508
# Cell 426 is connected to Cell 360
# Cell 426 is connected to Cell 359
# Cell 427 is connected to Cell 498
# Cell 427 is connected to Cell 169
# Cell 428 is connected to Cell 498
# Cell 428 is connected to Cell 169
# Cell 429 is connected to Cell 498
# Cell 429 is connected to Cell 169
# Cell 430 is connected to Cell 360
# Cell 430 is connected to Cell 359
# Cell 431 is connected to Cell 360
# Cell 431 is connected to Cell 359
# Cell 432 is connected to Cell 360
# Cell 432 is connected to Cell 359
# Cell 433 is connected to Cell 360
# Cell 433 is connected to Cell 359
# Cell 434 is connected to Cell 360
# Cell 434 is connected to Cell 359
# Cell 435 is connected to Cell 498
# Cell 435 is connected to Cell 169
# Cell 436 is connected to Cell 360
# Cell 436 is connected to Cell 359
# Cell 437 is connected to Cell 360
# Cell 437 is connected to Cell 359
# Cell 438 is connected to Cell 360
# Cell 438 is connected to Cell 359
# Cell 439 is connected to Cell 360
# Cell 439 is connected to Cell 359
# Cell 440 is connected to Cell 360
# Cell 440 is connected to Cell 359
# Cell 441 is connected to Cell 498
# Cell 441 is connected to Cell 169
# Cell 442 is connected to Cell 498
# Cell 442 is connected to Cell 169
# Cell 443 is connected to Cell 360
# Cell 443 is connected to Cell 359
# Cell 444 is connected to Cell 360
# Cell 444 is connected to Cell 359
# Cell 445 is connected to Cell 360
# Cell 445 is connected to Cell 359
# Cell 446 is connected to Cell 360
# Cell 446 is connected to Cell 359
# Cell 447 is connected to Cell 360
# Cell 447 is connected to Cell 359
# Cell 448 is connected to Cell 314
# Cell 448 is connected to Cell 503
# Cell 449 is connected to Cell 174
# Cell 449 is connected to Cell 74
# Cell 450 is connected to Cell 498
# Cell 450 is connected to Cell 169
# Cell 451 is connected to Cell 360
# Cell 451 is connected to Cell 359
# Cell 452 is connected to Cell 498
# Cell 452 is connected to Cell 169
# Cell 453 is connected to Cell 360
# Cell 453 is connected to Cell 359
# Cell 454 is connected to Cell 360
# Cell 454 is connected to Cell 359
# Cell 455 is connected to Cell 498
# Cell 455 is connected to Cell 169
# Cell 456 is connected to Cell 49750
# Cell 456 is connected to Cell 24516
# Cell 457 is connected to Cell 360
# Cell 457 is connected to Cell 359
# Cell 458 is connected to Cell 360
# Cell 458 is connected to Cell 359
# Cell 459 is connected to Cell 360
# Cell 459 is connected to Cell 359
# Cell 460 is connected to Cell 498
# Cell 460 is connected to Cell 169
# Cell 461 is connected to Cell 360
# Cell 461 is connected to Cell 359
# Cell 462 is connected to Cell 360
# Cell 462 is connected to Cell 359
# Cell 463 is connected to Cell 296
# Cell 463 is connected to Cell 417
# Cell 464 is connected to Cell 498
# Cell 464 is connected to Cell 169
# Cell 465 is connected to Cell 360
# Cell 465 is connected to Cell 359
# Cell 466 is connected to Cell 360
# Cell 466 is connected to Cell 359
# Cell 467 is connected to Cell 22
# Cell 467 is connected to Cell 508
# Cell 468 is connected to Cell 360
# Cell 468 is connected to Cell 359
# Cell 469 is connected to Cell 360
# Cell 469 is connected to Cell 359
# Cell 470 is connected to Cell 360
# Cell 470 is connected to Cell 359
# Cell 471 is connected to Cell 360
# Cell 471 is connected to Cell 359
# Cell 472 is connected to Cell 360
# Cell 472 is connected to Cell 359
# Cell 473 is connected to Cell 22
# Cell 473 is connected to Cell 508
# Cell 474 is connected to Cell 360
# Cell 474 is connected to Cell 359
# Cell 475 is connected to Cell 360
# Cell 475 is connected to Cell 359
# Cell 476 is connected to Cell 22
# Cell 476 is connected to Cell 508
# Cell 477 is connected to Cell 360
# Cell 477 is connected to Cell 359
# Cell 478 is connected to Cell 478
# Cell 478 is connected to Cell 46954
# Cell 479 is connected to Cell 360
# Cell 479 is connected to Cell 359
# Cell 480 is connected to Cell 279
# Cell 480 is connected to Cell 313
# Cell 481 is connected to Cell 360
# Cell 481 is connected to Cell 359
# Cell 482 is connected to Cell 360
# Cell 482 is connected to Cell 359
# Cell 483 is connected to Cell 360
# Cell 483 is connected to Cell 359
# Cell 484 is connected to Cell 498
# Cell 484 is connected to Cell 169
# Cell 485 is connected to Cell 360
# Cell 485 is connected to Cell 359
# Cell 486 is connected to Cell 296
# Cell 486 is connected to Cell 417
# Cell 487 is connected to Cell 22
# Cell 487 is connected to Cell 508
# Cell 488 is connected to Cell 360
# Cell 488 is connected to Cell 359
# Cell 489 is connected to Cell 360
# Cell 489 is connected to Cell 359
# Cell 490 is connected to Cell 360
# Cell 490 is connected to Cell 359
# Cell 491 is connected to Cell 360
# Cell 491 is connected to Cell 359
# Cell 492 is connected to Cell 360
# Cell 492 is connected to Cell 359
# Cell 493 is connected to Cell 22
# Cell 493 is connected to Cell 508
# Cell 494 is connected to Cell 360
# Cell 494 is connected to Cell 359
# Cell 495 is connected to Cell 360
# Cell 495 is connected to Cell 359
# Cell 496 is connected to Cell 360
# Cell 496 is connected to Cell 359
# Cell 497 is connected to Cell 360
# Cell 497 is connected to Cell 359
# Cell 498 is connected to Cell 498
# Cell 498 is connected to Cell 169
# Cell 499 is connected to Cell 360
# Cell 499 is connected to Cell 359
# Cell 500 is connected to Cell 314
# Cell 500 is connected to Cell 503
# Cell 501 is connected to Cell 360
# Cell 501 is connected to Cell 359
# Cell 502 is connected to Cell 95
# Cell 502 is connected to Cell 502
# Cell 503 is connected to Cell 314
# Cell 503 is connected to Cell 503
# Cell 504 is connected to Cell 360
# Cell 504 is connected to Cell 359
# Cell 505 is connected to Cell 360
# Cell 505 is connected to Cell 359
# Cell 506 is connected to Cell 510
# Cell 506 is connected to Cell 506
# Cell 507 is connected to Cell 360
# Cell 507 is connected to Cell 359
# Cell 508 is connected to Cell 22
# Cell 508 is connected to Cell 508
# Cell 509 is connected to Cell 22
# Cell 509 is connected to Cell 508
# Cell 510 is connected to Cell 510
# Cell 510 is connected to Cell 506
# Cell 511 is connected to Cell 360
# Cell 511 is connected to Cell 359
# Cell 512 is connected to Cell 360
# Cell 512 is connected to Cell 359
# Cell 513 is connected to Cell 360
# Cell 513 is connected to Cell 359
# Cell 514 is connected to Cell 360
# Cell 514 is connected to Cell 359
# Cell 515 is connected to Cell 360
# Cell 515 is connected to Cell 359
# Cell 516 is connected to Cell 360
# Cell 516 is connected to Cell 359
# Cell 517 is connected to Cell 360
# Cell 517 is connected to Cell 359
# Cell 518 is connected to Cell 498
# Cell 518 is connected to Cell 169
# Cell 519 is connected to Cell 360
# Cell 519 is connected to Cell 359
# Cell 520 is connected to Cell 498
# Cell 520 is connected to Cell 169
# Cell 521 is connected to Cell 360
# Cell 521 is connected to Cell 359
# Cell 522 is connected to Cell 330
# Cell 522 is connected to Cell 45180
# Cell 523 is connected to Cell 360
# Cell 523 is connected to Cell 359
# Cell 524 is connected to Cell 360
# Cell 524 is connected to Cell 359
# Cell 525 is connected to Cell 314
# Cell 525 is connected to Cell 503
# Cell 526 is connected to Cell 498
# Cell 526 is connected to Cell 169
# Cell 527 is connected to Cell 498
# Cell 527 is connected to Cell 169
# Cell 528 is connected to Cell 528
# Cell 528 is connected to Cell 94
# Cell 529 is connected to Cell 174
# Cell 529 is connected to Cell 74
# Cell 530 is connected to Cell 360
# Cell 530 is connected to Cell 359
# Cell 531 is connected to Cell 360
# Cell 531 is connected to Cell 359
# Cell 532 is connected to Cell 360
# Cell 532 is connected to Cell 359
# Cell 533 is connected to Cell 510
# Cell 533 is connected to Cell 506
# Cell 534 is connected to Cell 27181
# Cell 534 is connected to Cell 2651
# Cell 535 is connected to Cell 360
# Cell 535 is connected to Cell 359
# Cell 536 is connected to Cell 360
# Cell 536 is connected to Cell 359
# Cell 537 is connected to Cell 360
# Cell 537 is connected to Cell 359
# Cell 538 is connected to Cell 360
# Cell 538 is connected to Cell 359
# Cell 539 is connected to Cell 539
# Cell 539 is connected to Cell 8899
# Cell 540 is connected to Cell 174
# Cell 540 is connected to Cell 74
# Cell 541 is connected to Cell 360
# Cell 541 is connected to Cell 359
# Cell 542 is connected to Cell 360
# Cell 542 is connected to Cell 359
# Cell 543 is connected to Cell 174
# Cell 543 is connected to Cell 74
# Cell 544 is connected to Cell 360
# Cell 544 is connected to Cell 359
# Cell 545 is connected to Cell 360
# Cell 545 is connected to Cell 359
# Cell 546 is connected to Cell 498
# Cell 546 is connected to Cell 169
# Cell 547 is connected to Cell 34612
# Cell 547 is connected to Cell 43258
# Cell 548 is connected to Cell 305
# Cell 548 is connected to Cell 573
# Cell 549 is connected to Cell 95
# Cell 549 is connected to Cell 502
# Cell 550 is connected to Cell 510
# Cell 550 is connected to Cell 506
# Cell 551 is connected to Cell 360
# Cell 551 is connected to Cell 359
# Cell 552 is connected to Cell 174
# Cell 552 is connected to Cell 74
# Cell 553 is connected to Cell 360
# Cell 553 is connected to Cell 359
# Cell 554 is connected to Cell 314
# Cell 554 is connected to Cell 503
# Cell 555 is connected to Cell 360
# Cell 555 is connected to Cell 359
# Cell 556 is connected to Cell 360
# Cell 556 is connected to Cell 359
# Cell 557 is connected to Cell 22
# Cell 557 is connected to Cell 508
# Cell 558 is connected to Cell 22
# Cell 558 is connected to Cell 508
# Cell 559 is connected to Cell 360
# Cell 559 is connected to Cell 359
# Cell 560 is connected to Cell 498
# Cell 560 is connected to Cell 169
# Cell 561 is connected to Cell 498
# Cell 561 is connected to Cell 169
# Cell 562 is connected to Cell 562
# Cell 562 is connected to Cell 39547
# Cell 563 is connected to Cell 174
# Cell 563 is connected to Cell 74
# Cell 564 is connected to Cell 174
# Cell 564 is connected to Cell 74
# Cell 565 is connected to Cell 22
# Cell 565 is connected to Cell 508
# Cell 566 is connected to Cell 498
# Cell 566 is connected to Cell 169
# Cell 567 is connected to Cell 360
# Cell 567 is connected to Cell 359
# Cell 568 is connected to Cell 174
# Cell 568 is connected to Cell 74
# Cell 569 is connected to Cell 360
# Cell 569 is connected to Cell 359
# Cell 570 is connected to Cell 360
# Cell 570 is connected to Cell 359
# Cell 571 is connected to Cell 360
# Cell 571 is connected to Cell 359
# Cell 572 is connected to Cell 360
# Cell 572 is connected to Cell 359
# Cell 573 is connected to Cell 305
# Cell 573 is connected to Cell 573
# Cell 574 is connected to Cell 174
# Cell 574 is connected to Cell 74
# Cell 575 is connected to Cell 360
# Cell 575 is connected to Cell 359
# Cell 576 is connected to Cell 174
# Cell 576 is connected to Cell 74
# Cell 577 is connected to Cell 174
# Cell 577 is connected to Cell 74
# Cell 578 is connected to Cell 174
# Cell 578 is connected to Cell 74
# Cell 579 is connected to Cell 539
# Cell 579 is connected to Cell 8899
# Cell 580 is connected to Cell 360
# Cell 580 is connected to Cell 359
# Cell 581 is connected to Cell 360
# Cell 581 is connected to Cell 359
# Cell 582 is connected to Cell 360
# Cell 582 is connected to Cell 359
# Cell 583 is connected to Cell 360
# Cell 583 is connected to Cell 359
# Cell 584 is connected to Cell 498
# Cell 584 is connected to Cell 169
# Cell 585 is connected to Cell 174
# Cell 585 is connected to Cell 74
# Cell 586 is connected to Cell 360
# Cell 586 is connected to Cell 359
# Cell 587 is connected to Cell 360
# Cell 587 is connected to Cell 359
# Cell 588 is connected to Cell 174
# Cell 588 is connected to Cell 74
# Cell 589 is connected to Cell 174
# Cell 589 is connected to Cell 74
# Cell 590 is connected to Cell 590
# Cell 590 is connected to Cell 12500
# Cell 591 is connected to Cell 528
# Cell 591 is connected to Cell 94
# Cell 592 is connected to Cell 174
# Cell 592 is connected to Cell 74
# Cell 593 is connected to Cell 174
# Cell 593 is connected to Cell 74
# Cell 594 is connected to Cell 174
# Cell 594 is connected to Cell 74
# Cell 595 is connected to Cell 360
# Cell 595 is connected to Cell 359
# Cell 596 is connected to Cell 791
# Cell 596 is connected to Cell 792
# Cell 597 is connected to Cell 791
# Cell 597 is connected to Cell 792
# Cell 598 is connected to Cell 791
# Cell 598 is connected to Cell 792
# Cell 599 is connected to Cell 791
# Cell 599 is connected to Cell 792
# Cell 600 is connected to Cell 791
# Cell 600 is connected to Cell 792
# Cell 601 is connected to Cell 791
# Cell 601 is connected to Cell 792
# Cell 602 is connected to Cell 791
# Cell 602 is connected to Cell 792
# Cell 603 is connected to Cell 791
# Cell 603 is connected to Cell 792
# Cell 604 is connected to Cell 791
# Cell 604 is connected to Cell 792
# Cell 605 is connected to Cell 791
# Cell 605 is connected to Cell 792
# Cell 606 is connected to Cell 791
# Cell 606 is connected to Cell 792
# Cell 607 is connected to Cell 791
# Cell 607 is connected to Cell 792
# Cell 608 is connected to Cell 791
# Cell 608 is connected to Cell 792
# Cell 609 is connected to Cell 791
# Cell 609 is connected to Cell 792
# Cell 610 is connected to Cell 791
# Cell 610 is connected to Cell 792
# Cell 611 is connected to Cell 791
# Cell 611 is connected to Cell 792
# Cell 612 is connected to Cell 791
# Cell 612 is connected to Cell 792
# Cell 613 is connected to Cell 791
# Cell 613 is connected to Cell 792
# Cell 614 is connected to Cell 791
# Cell 614 is connected to Cell 792
# Cell 615 is connected to Cell 791
# Cell 615 is connected to Cell 792
# Cell 616 is connected to Cell 791
# Cell 616 is connected to Cell 792
# Cell 617 is connected to Cell 867
# Cell 617 is connected to Cell 1072
# Cell 618 is connected to Cell 791
# Cell 618 is connected to Cell 792
# Cell 619 is connected to Cell 791
# Cell 619 is connected to Cell 792
# Cell 620 is connected to Cell 791
# Cell 620 is connected to Cell 792
# Cell 621 is connected to Cell 791
# Cell 621 is connected to Cell 792
# Cell 622 is connected to Cell 986
# Cell 622 is connected to Cell 1128
# Cell 623 is connected to Cell 791
# Cell 623 is connected to Cell 792
# Cell 624 is connected to Cell 791
# Cell 624 is connected to Cell 792
# Cell 625 is connected to Cell 791
# Cell 625 is connected to Cell 792
# Cell 626 is connected to Cell 791
# Cell 626 is connected to Cell 792
# Cell 627 is connected to Cell 791
# Cell 627 is connected to Cell 792
# Cell 628 is connected to Cell 791
# Cell 628 is connected to Cell 792
# Cell 629 is connected to Cell 791
# Cell 629 is connected to Cell 792
# Cell 630 is connected to Cell 791
# Cell 630 is connected to Cell 792
# Cell 631 is connected to Cell 791
# Cell 631 is connected to Cell 792
# Cell 632 is connected to Cell 791
# Cell 632 is connected to Cell 792
# Cell 633 is connected to Cell 1148
# Cell 633 is connected to Cell 880
# Cell 634 is connected to Cell 791
# Cell 634 is connected to Cell 792
# Cell 635 is connected to Cell 791
# Cell 635 is connected to Cell 792
# Cell 636 is connected to Cell 986
# Cell 636 is connected to Cell 1128
# Cell 637 is connected to Cell 791
# Cell 637 is connected to Cell 792
# Cell 638 is connected to Cell 867
# Cell 638 is connected to Cell 1072
# Cell 639 is connected to Cell 1148
# Cell 639 is connected to Cell 880
# Cell 640 is connected to Cell 791
# Cell 640 is connected to Cell 792
# Cell 641 is connected to Cell 791
# Cell 641 is connected to Cell 792
# Cell 642 is connected to Cell 791
# Cell 642 is connected to Cell 792
# Cell 643 is connected to Cell 791
# Cell 643 is connected to Cell 792
# Cell 644 is connected to Cell 867
# Cell 644 is connected to Cell 1072
# Cell 645 is connected to Cell 791
# Cell 645 is connected to Cell 792
# Cell 646 is connected to Cell 791
# Cell 646 is connected to Cell 792
# Cell 647 is connected to Cell 791
# Cell 647 is connected to Cell 792
# Cell 648 is connected to Cell 791
# Cell 648 is connected to Cell 792
# Cell 649 is connected to Cell 867
# Cell 649 is connected to Cell 1072
# Cell 650 is connected to Cell 791
# Cell 650 is connected to Cell 792
# Cell 651 is connected to Cell 651
# Cell 651 is connected to Cell 960
# Cell 652 is connected to Cell 791
# Cell 652 is connected to Cell 792
# Cell 653 is connected to Cell 867
# Cell 653 is connected to Cell 1072
# Cell 654 is connected to Cell 791
# Cell 654 is connected to Cell 792
# Cell 655 is connected to Cell 986
# Cell 655 is connected to Cell 1128
# Cell 656 is connected to Cell 791
# Cell 656 is connected to Cell 792
# Cell 657 is connected to Cell 791
# Cell 657 is connected to Cell 792
# Cell 658 is connected to Cell 791
# Cell 658 is connected to Cell 792
# Cell 659 is connected to Cell 986
# Cell 659 is connected to Cell 1128
# Cell 660 is connected to Cell 791
# Cell 660 is connected to Cell 792
# Cell 661 is connected to Cell 791
# Cell 661 is connected to Cell 792
# Cell 662 is connected to Cell 791
# Cell 662 is connected to Cell 792
# Cell 663 is connected to Cell 791
# Cell 663 is connected to Cell 792
# Cell 664 is connected to Cell 791
# Cell 664 is connected to Cell 792
# Cell 665 is connected to Cell 791
# Cell 665 is connected to Cell 792
# Cell 666 is connected to Cell 791
# Cell 666 is connected to Cell 792
# Cell 667 is connected to Cell 791
# Cell 667 is connected to Cell 792
# Cell 668 is connected to Cell 791
# Cell 668 is connected to Cell 792
# Cell 669 is connected to Cell 28743
# Cell 669 is connected to Cell 16798
# Cell 670 is connected to Cell 867
# Cell 670 is connected to Cell 1072
# Cell 671 is connected to Cell 791
# Cell 671 is connected to Cell 792
# Cell 672 is connected to Cell 791
# Cell 672 is connected to Cell 792
# Cell 673 is connected to Cell 791
# Cell 673 is connected to Cell 792
# Cell 674 is connected to Cell 986
# Cell 674 is connected to Cell 1128
# Cell 675 is connected to Cell 791
# Cell 675 is connected to Cell 792
# Cell 676 is connected to Cell 791
# Cell 676 is connected to Cell 792
# Cell 677 is connected to Cell 791
# Cell 677 is connected to Cell 792
# Cell 678 is connected to Cell 791
# Cell 678 is connected to Cell 792
# Cell 679 is connected to Cell 791
# Cell 679 is connected to Cell 792
# Cell 680 is connected to Cell 791
# Cell 680 is connected to Cell 792
# Cell 681 is connected to Cell 791
# Cell 681 is connected to Cell 792
# Cell 682 is connected to Cell 791
# Cell 682 is connected to Cell 792
# Cell 683 is connected to Cell 791
# Cell 683 is connected to Cell 792
# Cell 684 is connected to Cell 791
# Cell 684 is connected to Cell 792
# Cell 685 is connected to Cell 791
# Cell 685 is connected to Cell 792
# Cell 686 is connected to Cell 791
# Cell 686 is connected to Cell 792
# Cell 687 is connected to Cell 791
# Cell 687 is connected to Cell 792
# Cell 688 is connected to Cell 791
# Cell 688 is connected to Cell 792
# Cell 689 is connected to Cell 867
# Cell 689 is connected to Cell 1072
# Cell 690 is connected to Cell 986
# Cell 690 is connected to Cell 1128
# Cell 691 is connected to Cell 791
# Cell 691 is connected to Cell 792
# Cell 692 is connected to Cell 986
# Cell 692 is connected to Cell 1128
# Cell 693 is connected to Cell 867
# Cell 693 is connected to Cell 1072
# Cell 694 is connected to Cell 1148
# Cell 694 is connected to Cell 880
# Cell 695 is connected to Cell 791
# Cell 695 is connected to Cell 792
# Cell 696 is connected to Cell 791
# Cell 696 is connected to Cell 792
# Cell 697 is connected to Cell 1138
# Cell 697 is connected to Cell 813
# Cell 698 is connected to Cell 791
# Cell 698 is connected to Cell 792
# Cell 699 is connected to Cell 791
# Cell 699 is connected to Cell 792
# Cell 700 is connected to Cell 791
# Cell 700 is connected to Cell 792
# Cell 701 is connected to Cell 791
# Cell 701 is connected to Cell 792
# Cell 702 is connected to Cell 791
# Cell 702 is connected to Cell 792
# Cell 703 is connected to Cell 791
# Cell 703 is connected to Cell 792
# Cell 704 is connected to Cell 791
# Cell 704 is connected to Cell 792
# Cell 705 is connected to Cell 791
# Cell 705 is connected to Cell 792
# Cell 706 is connected to Cell 791
# Cell 706 is connected to Cell 792
# Cell 707 is connected to Cell 791
# ...
# Cell 49791 is connected to Cell 47664
# Cell 49791 is connected to Cell 47666
# Cell 49792 is connected to Cell 47664
# Cell 49792 is connected to Cell 47666
# Cell 49793 is connected to Cell 47664
# Cell 49793 is connected to Cell 47666
# Cell 49794 is connected to Cell 47664
# Cell 49794 is connected to Cell 47666
# Cell 49795 is connected to Cell 47183
# Cell 49795 is connected to Cell 46648
# Cell 49796 is connected to Cell 48409
# Cell 49796 is connected to Cell 46720
# Cell 49797 is connected to Cell 47664
# Cell 49797 is connected to Cell 47666
# Cell 49798 is connected to Cell 47664
# Cell 49798 is connected to Cell 47666
# Cell 49799 is connected to Cell 47664
# Cell 49799 is connected to Cell 47666
# Cell 49800 is connected to Cell 47189
# Cell 49800 is connected to Cell 48265
# Cell 49801 is connected to Cell 47664
# Cell 49801 is connected to Cell 47666
# Cell 49802 is connected to Cell 47664
# Cell 49802 is connected to Cell 47666
# Cell 49803 is connected to Cell 47664
# Cell 49803 is connected to Cell 47666
# Cell 49804 is connected to Cell 48503
# Cell 49804 is connected to Cell 48696
# Cell 49805 is connected to Cell 47189
# Cell 49805 is connected to Cell 48265
# Cell 49806 is connected to Cell 47664
# Cell 49806 is connected to Cell 47666
# Cell 49807 is connected to Cell 47189
# Cell 49807 is connected to Cell 48265
# Cell 49808 is connected to Cell 47664
# Cell 49808 is connected to Cell 47666
# Cell 49809 is connected to Cell 48503
# Cell 49809 is connected to Cell 48696
# Cell 49810 is connected to Cell 48409
# Cell 49810 is connected to Cell 46720
# Cell 49811 is connected to Cell 47427
# Cell 49811 is connected to Cell 47430
# Cell 49812 is connected to Cell 49387
# Cell 49812 is connected to Cell 48404
# Cell 49813 is connected to Cell 47427
# Cell 49813 is connected to Cell 47430
# Cell 49814 is connected to Cell 47664
# Cell 49814 is connected to Cell 47666
# Cell 49815 is connected to Cell 47189
# Cell 49815 is connected to Cell 48265
# Cell 49816 is connected to Cell 47183
# Cell 49816 is connected to Cell 46648
# Cell 49817 is connected to Cell 47664
# Cell 49817 is connected to Cell 47666
# Cell 49818 is connected to Cell 47664
# Cell 49818 is connected to Cell 47666
# Cell 49819 is connected to Cell 49387
# Cell 49819 is connected to Cell 48404
# Cell 49820 is connected to Cell 47371
# Cell 49820 is connected to Cell 48052
# Cell 49821 is connected to Cell 47181
# Cell 49821 is connected to Cell 49959
# Cell 49822 is connected to Cell 48409
# Cell 49822 is connected to Cell 46720
# Cell 49823 is connected to Cell 13291
# Cell 49823 is connected to Cell 14999
# Cell 49824 is connected to Cell 48409
# Cell 49824 is connected to Cell 46720
# Cell 49825 is connected to Cell 48503
# Cell 49825 is connected to Cell 48696
# Cell 49826 is connected to Cell 47664
# Cell 49826 is connected to Cell 47666
# Cell 49827 is connected to Cell 47664
# Cell 49827 is connected to Cell 47666
# Cell 49828 is connected to Cell 47664
# Cell 49828 is connected to Cell 47666
# Cell 49829 is connected to Cell 47189
# Cell 49829 is connected to Cell 48265
# Cell 49830 is connected to Cell 47189
# Cell 49830 is connected to Cell 48265
# Cell 49831 is connected to Cell 47371
# Cell 49831 is connected to Cell 48052
# Cell 49832 is connected to Cell 47664
# Cell 49832 is connected to Cell 47666
# Cell 49833 is connected to Cell 47664
# Cell 49833 is connected to Cell 47666
# Cell 49834 is connected to Cell 48276
# Cell 49834 is connected to Cell 47215
# Cell 49835 is connected to Cell 48409
# Cell 49835 is connected to Cell 46720
# Cell 49836 is connected to Cell 48409
# Cell 49836 is connected to Cell 46720
# Cell 49837 is connected to Cell 47183
# Cell 49837 is connected to Cell 46648
# Cell 49838 is connected to Cell 47664
# Cell 49838 is connected to Cell 47666
# Cell 49839 is connected to Cell 47633
# Cell 49839 is connected to Cell 47059
# Cell 49840 is connected to Cell 48503
# Cell 49840 is connected to Cell 48696
# Cell 49841 is connected to Cell 47664
# Cell 49841 is connected to Cell 47666
# Cell 49842 is connected to Cell 48409
# Cell 49842 is connected to Cell 46720
# Cell 49843 is connected to Cell 47664
# Cell 49843 is connected to Cell 47666
# Cell 49844 is connected to Cell 49387
# Cell 49844 is connected to Cell 48404
# Cell 49845 is connected to Cell 48409
# Cell 49845 is connected to Cell 46720
# Cell 49846 is connected to Cell 47664
# Cell 49846 is connected to Cell 47666
# Cell 49847 is connected to Cell 48503
# Cell 49847 is connected to Cell 48696
# Cell 49848 is connected to Cell 47664
# Cell 49848 is connected to Cell 47666
# Cell 49849 is connected to Cell 47664
# Cell 49849 is connected to Cell 47666
# Cell 49850 is connected to Cell 47371
# Cell 49850 is connected to Cell 48052
# Cell 49851 is connected to Cell 47189
# Cell 49851 is connected to Cell 48265
# Cell 49852 is connected to Cell 47189
# Cell 49852 is connected to Cell 48265
# Cell 49853 is connected to Cell 47664
# Cell 49853 is connected to Cell 47666
# Cell 49854 is connected to Cell 48409
# Cell 49854 is connected to Cell 46720
# Cell 49855 is connected to Cell 48447
# Cell 49855 is connected to Cell 49630
# Cell 49856 is connected to Cell 47189
# Cell 49856 is connected to Cell 48265
# Cell 49857 is connected to Cell 48409
# Cell 49857 is connected to Cell 46720
# Cell 49858 is connected to Cell 47181
# Cell 49858 is connected to Cell 49959
# Cell 49859 is connected to Cell 48409
# Cell 49859 is connected to Cell 46720
# Cell 49860 is connected to Cell 47664
# Cell 49860 is connected to Cell 47666
# Cell 49861 is connected to Cell 48409
# Cell 49861 is connected to Cell 46720
# Cell 49862 is connected to Cell 48503
# Cell 49862 is connected to Cell 48696
# Cell 49863 is connected to Cell 47664
# Cell 49863 is connected to Cell 47666
# Cell 49864 is connected to Cell 47189
# Cell 49864 is connected to Cell 48265
# Cell 49865 is connected to Cell 48409
# Cell 49865 is connected to Cell 46720
# Cell 49866 is connected to Cell 47189
# Cell 49866 is connected to Cell 48265
# Cell 49867 is connected to Cell 48409
# Cell 49867 is connected to Cell 46720
# Cell 49868 is connected to Cell 47427
# Cell 49868 is connected to Cell 47430
# Cell 49869 is connected to Cell 49387
# Cell 49869 is connected to Cell 48404
# Cell 49870 is connected to Cell 47664
# Cell 49870 is connected to Cell 47666
# Cell 49871 is connected to Cell 47664
# Cell 49871 is connected to Cell 47666
# Cell 49872 is connected to Cell 48409
# Cell 49872 is connected to Cell 46720
# Cell 49873 is connected to Cell 47664
# Cell 49873 is connected to Cell 47666
# Cell 49874 is connected to Cell 47189
# Cell 49874 is connected to Cell 48265
# Cell 49875 is connected to Cell 48409
# Cell 49875 is connected to Cell 46720
# Cell 49876 is connected to Cell 48409
# Cell 49876 is connected to Cell 46720
# Cell 49877 is connected to Cell 47664
# Cell 49877 is connected to Cell 47666
# Cell 49878 is connected to Cell 47371
# Cell 49878 is connected to Cell 48052
# Cell 49879 is connected to Cell 47427
# Cell 49879 is connected to Cell 47430
# Cell 49880 is connected to Cell 48873
# Cell 49880 is connected to Cell 48396
# Cell 49881 is connected to Cell 48503
# Cell 49881 is connected to Cell 48696
# Cell 49882 is connected to Cell 47664
# Cell 49882 is connected to Cell 47666
# Cell 49883 is connected to Cell 47189
# Cell 49883 is connected to Cell 48265
# Cell 49884 is connected to Cell 47189
# Cell 49884 is connected to Cell 48265
# Cell 49885 is connected to Cell 47664
# Cell 49885 is connected to Cell 47666
# Cell 49886 is connected to Cell 47664
# Cell 49886 is connected to Cell 47666
# Cell 49887 is connected to Cell 47664
# Cell 49887 is connected to Cell 47666
# Cell 49888 is connected to Cell 48409
# Cell 49888 is connected to Cell 46720
# Cell 49889 is connected to Cell 47664
# Cell 49889 is connected to Cell 47666
# Cell 49890 is connected to Cell 47664
# Cell 49890 is connected to Cell 47666
# Cell 49891 is connected to Cell 47664
# Cell 49891 is connected to Cell 47666
# Cell 49892 is connected to Cell 49470
# Cell 49892 is connected to Cell 46961
# Cell 49893 is connected to Cell 49161
# Cell 49893 is connected to Cell 49373
# Cell 49894 is connected to Cell 47664
# Cell 49894 is connected to Cell 47666
# Cell 49895 is connected to Cell 24303
# Cell 49895 is connected to Cell 22926
# Cell 49896 is connected to Cell 47189
# Cell 49896 is connected to Cell 48265
# Cell 49897 is connected to Cell 47664
# Cell 49897 is connected to Cell 47666
# Cell 49898 is connected to Cell 48409
# Cell 49898 is connected to Cell 46720
# Cell 49899 is connected to Cell 47664
# Cell 49899 is connected to Cell 47666
# Cell 49900 is connected to Cell 47183
# Cell 49900 is connected to Cell 46648
# Cell 49901 is connected to Cell 48409
# Cell 49901 is connected to Cell 46720
# Cell 49902 is connected to Cell 47664
# Cell 49902 is connected to Cell 47666
# Cell 49903 is connected to Cell 47664
# Cell 49903 is connected to Cell 47666
# Cell 49904 is connected to Cell 47189
# Cell 49904 is connected to Cell 48265
# Cell 49905 is connected to Cell 47664
# Cell 49905 is connected to Cell 47666
# Cell 49906 is connected to Cell 48409
# Cell 49906 is connected to Cell 46720
# Cell 49907 is connected to Cell 47664
# Cell 49907 is connected to Cell 47666
# Cell 49908 is connected to Cell 49387
# Cell 49908 is connected to Cell 48404
# Cell 49909 is connected to Cell 47664
# Cell 49909 is connected to Cell 47666
# Cell 49910 is connected to Cell 47664
# Cell 49910 is connected to Cell 47666
# Cell 49911 is connected to Cell 47427
# Cell 49911 is connected to Cell 47430
# Cell 49912 is connected to Cell 47664
# Cell 49912 is connected to Cell 47666
# Cell 49913 is connected to Cell 48409
# Cell 49913 is connected to Cell 46720
# Cell 49914 is connected to Cell 47664
# Cell 49914 is connected to Cell 47666
# Cell 49915 is connected to Cell 48409
# Cell 49915 is connected to Cell 46720
# Cell 49916 is connected to Cell 47189
# Cell 49916 is connected to Cell 48265
# Cell 49917 is connected to Cell 47427
# Cell 49917 is connected to Cell 47430
# Cell 49918 is connected to Cell 47189
# Cell 49918 is connected to Cell 48265
# Cell 49919 is connected to Cell 47664
# Cell 49919 is connected to Cell 47666
# Cell 49920 is connected to Cell 47664
# Cell 49920 is connected to Cell 47666
# Cell 49921 is connected to Cell 47664
# Cell 49921 is connected to Cell 47666
# Cell 49922 is connected to Cell 47664
# Cell 49922 is connected to Cell 47666
# Cell 49923 is connected to Cell 47664
# Cell 49923 is connected to Cell 47666
# Cell 49924 is connected to Cell 35029
# Cell 49924 is connected to Cell 3557
# Cell 49925 is connected to Cell 47427
# Cell 49925 is connected to Cell 47430
# Cell 49926 is connected to Cell 47664
# Cell 49926 is connected to Cell 47666
# Cell 49927 is connected to Cell 47189
# Cell 49927 is connected to Cell 48265
# Cell 49928 is connected to Cell 12855
# Cell 49928 is connected to Cell 16723
# Cell 49929 is connected to Cell 47664
# Cell 49929 is connected to Cell 47666
# Cell 49930 is connected to Cell 48409
# Cell 49930 is connected to Cell 46720
# Cell 49931 is connected to Cell 48409
# Cell 49931 is connected to Cell 46720
# Cell 49932 is connected to Cell 49387
# Cell 49932 is connected to Cell 48404
# Cell 49933 is connected to Cell 47664
# Cell 49933 is connected to Cell 47666
# Cell 49934 is connected to Cell 48409
# Cell 49934 is connected to Cell 46720
# Cell 49935 is connected to Cell 47664
# Cell 49935 is connected to Cell 47666
# Cell 49936 is connected to Cell 47664
# Cell 49936 is connected to Cell 47666
# Cell 49937 is connected to Cell 47664
# Cell 49937 is connected to Cell 47666
# Cell 49938 is connected to Cell 49387
# Cell 49938 is connected to Cell 48404
# Cell 49939 is connected to Cell 47664
# Cell 49939 is connected to Cell 47666
# Cell 49940 is connected to Cell 47664
# Cell 49940 is connected to Cell 47666
# Cell 49941 is connected to Cell 47189
# Cell 49941 is connected to Cell 48265
# Cell 49942 is connected to Cell 49942
# Cell 49942 is connected to Cell 46894
# Cell 49943 is connected to Cell 48409
# Cell 49943 is connected to Cell 46720
# Cell 49944 is connected to Cell 47371
# Cell 49944 is connected to Cell 48052
# Cell 49945 is connected to Cell 47664
# Cell 49945 is connected to Cell 47666
# Cell 49946 is connected to Cell 48409
# Cell 49946 is connected to Cell 46720
# Cell 49947 is connected to Cell 47664
# Cell 49947 is connected to Cell 47666
# Cell 49948 is connected to Cell 48409
# Cell 49948 is connected to Cell 46720
# Cell 49949 is connected to Cell 12075
# Cell 49949 is connected to Cell 37562
# Cell 49950 is connected to Cell 47189
# Cell 49950 is connected to Cell 48265
# Cell 49951 is connected to Cell 48409
# Cell 49951 is connected to Cell 46720
# Cell 49952 is connected to Cell 47427
# Cell 49952 is connected to Cell 47430
# Cell 49953 is connected to Cell 47664
# Cell 49953 is connected to Cell 47666
# Cell 49954 is connected to Cell 9325
# Cell 49954 is connected to Cell 30434
# Cell 49955 is connected to Cell 48276
# Cell 49955 is connected to Cell 47215
# Cell 49956 is connected to Cell 47664
# Cell 49956 is connected to Cell 47666
# Cell 49957 is connected to Cell 48503
# Cell 49957 is connected to Cell 48696
# Cell 49958 is connected to Cell 47189
# Cell 49958 is connected to Cell 48265
# Cell 49959 is connected to Cell 47181
# Cell 49959 is connected to Cell 49959
# Cell 49960 is connected to Cell 47189
# Cell 49960 is connected to Cell 48265
# Cell 49961 is connected to Cell 48409
# Cell 49961 is connected to Cell 46720
# Cell 49962 is connected to Cell 47664
# Cell 49962 is connected to Cell 47666
# Cell 49963 is connected to Cell 47664
# Cell 49963 is connected to Cell 47666
# Cell 49964 is connected to Cell 47664
# Cell 49964 is connected to Cell 47666
# Cell 49965 is connected to Cell 47664
# Cell 49965 is connected to Cell 47666
# Cell 49966 is connected to Cell 48409
# Cell 49966 is connected to Cell 46720
# Cell 49967 is connected to Cell 47664
# Cell 49967 is connected to Cell 47666
# Cell 49968 is connected to Cell 47664
# Cell 49968 is connected to Cell 47666
# Cell 49969 is connected to Cell 49351
# Cell 49969 is connected to Cell 30481
# Cell 49970 is connected to Cell 47664
# Cell 49970 is connected to Cell 47666
# Cell 49971 is connected to Cell 47189
# Cell 49971 is connected to Cell 48265
# Cell 49972 is connected to Cell 27725
# Cell 49972 is connected to Cell 30148
# Cell 49973 is connected to Cell 47664
# Cell 49973 is connected to Cell 47666
# Cell 49974 is connected to Cell 47189
# Cell 49974 is connected to Cell 48265
# Cell 49975 is connected to Cell 47664
# Cell 49975 is connected to Cell 47666
# Cell 49976 is connected to Cell 47427
# Cell 49976 is connected to Cell 47430
# Cell 49977 is connected to Cell 47664
# Cell 49977 is connected to Cell 47666
# Cell 49978 is connected to Cell 47664
# Cell 49978 is connected to Cell 47666
# Cell 49979 is connected to Cell 47664
# Cell 49979 is connected to Cell 47666
# Cell 49980 is connected to Cell 47427
# Cell 49980 is connected to Cell 47430
# Cell 49981 is connected to Cell 47664
# Cell 49981 is connected to Cell 47666
# Cell 49982 is connected to Cell 47664
# Cell 49982 is connected to Cell 47666
# Cell 49983 is connected to Cell 48409
# Cell 49983 is connected to Cell 46720
# Cell 49984 is connected to Cell 47189
# Cell 49984 is connected to Cell 48265
# Cell 49985 is connected to Cell 49387
# Cell 49985 is connected to Cell 48404
# Cell 49986 is connected to Cell 47389
# Cell 49986 is connected to Cell 46985
# Cell 49987 is connected to Cell 48503
# Cell 49987 is connected to Cell 48696
# Cell 49988 is connected to Cell 47664
# Cell 49988 is connected to Cell 47666
# Cell 49989 is connected to Cell 48276
# Cell 49989 is connected to Cell 47215
# Cell 49990 is connected to Cell 47664
# Cell 49990 is connected to Cell 47666
# Cell 49991 is connected to Cell 47664
# Cell 49991 is connected to Cell 47666
# Cell 49992 is connected to Cell 47664
# Cell 49992 is connected to Cell 47666
# Cell 49993 is connected to Cell 47189
# Cell 49993 is connected to Cell 48265
# Cell 49994 is connected to Cell 48409
# Cell 49994 is connected to Cell 46720
# Cell 49995 is connected to Cell 47664
# Cell 49995 is connected to Cell 47666
# Cell 49996 is connected to Cell 47189
# Cell 49996 is connected to Cell 48265
# Cell 49997 is connected to Cell 48409
# Cell 49997 is connected to Cell 46720
# Cell 49998 is connected to Cell 47664
# Cell 49998 is connected to Cell 47666
# Cell 49999 is connected to Cell 47664
# Cell 49999 is connected to Cell 47666
# [387, 9220, 42887, 9116, 239, 43504, 22191, 43539, 24500, 42847, 43324, 36222, 43519]

# %%
class GraphSAGE(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers=2):
        super(GraphSAGE, self).__init__()
        self.convs = torch.nn.ModuleList()
        self.convs.append(SAGEConv(in_channels, hidden_channels))  
        
        for _ in range(num_layers - 2):  
            self.convs.append(SAGEConv(hidden_channels, hidden_channels))
        
        self.convs.append(SAGEConv(hidden_channels, out_channels))  

    def forward(self, x, edge_index):
        for conv in self.convs[:-1]: 
            x = conv(x, edge_index)
            x = F.relu(x)
            x = F.dropout(x, p=0.5, training=self.training)
        x = self.convs[-1](x, edge_index) 
        return x
